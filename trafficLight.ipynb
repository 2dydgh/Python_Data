# %%
import pandas as pd
# 파일을 올바른 인코딩으로 읽어오기 (예: UTF-8)
df = pd.read_csv('trafficLight.csv', encoding='euc-kr')
df
# Out:
#      자치구  설치수량(조)
# 0    중랑구        2
# 1    강서구        4
# 2    관악구       46
# 3    서초구        4
# 4    광진구      156
# 5    용산구       10
# 6    마포구       18
# 7    동작구        8
# 8    강남구        8
# 9    송파구       28
# 10  서대문구        8
# 11    중구        2
# 12   종로구        6
# 13  영등포구        2
# 14   강북구        2
# 15   금천구       10
# 16   성동구       28
# 17   은평구       60
# 18   노원구       24
# 19   성북구       33

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt

grouped_data = df.groupby(['자치구']).sum()
colors = ['#f94144', '#f3722c', '#f8961e','#f9844a','#f9c74f','#90be6d','#43aa8b','#4d908e','#4d908e','#577590','#277da1']
explode = [0.14 if typ == '횡단중' else 0.04 for typ in grouped_data.index]

grouped_data['설치수량(조)'].plot(title = "서울시 보행신호 음성안내 보조장치 설치현황", kind='bar',figsize = (15,5), rot=45,color=colors, alpha=0.5)
plt.show()
