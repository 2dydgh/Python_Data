# %%
# "파이썬" 키워드 검색 후 인기 게시글 9개
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

options = webdriver.ChromeOptions()
options.add_argument("--user-data-dir=C:\\Users\\user\\Desktop\\MyChrome")

service = Service()
d = webdriver.Chrome(service=service, options=options)
    
try:
    d.get("https://www.instagram.com/")    
    time.sleep(5)
    
    buttons = d.find_elements(By.CSS_SELECTOR, ".xvy4d1p")
    search_button = buttons[2]
    
    ac = ActionChains(d)
    ac.move_to_element(search_button)
    ac.click()
    ac.pause(1)
    ac.perform()
    
    elem = d.find_element(By.CSS_SELECTOR, ".x7xwk5j")
    ac = ActionChains(d)
    ac.move_to_element(elem)
    ac.click()
    ac.send_keys("#파이썬")
    ac.send_keys(Keys.RETURN)
    ac.pause(2)
    ac.move_by_offset(0,100)  # 현재 커서 위치로부터 offset 만큼(여기서는 y축으로 100아래) 이동하라
    ac.click()
    ac.perform()
    time.sleep(5)
    
    posts = d.find_elements(By.CSS_SELECTOR, "._aa8k")
    for post in posts:
        ac = ActionChains(d)
        ac.click(post)
        ac.pause(1)
        ac.perform()
        
        content = d.find_element(By.CSS_SELECTOR, "._a9zs > ._aade")
        print(content.text)
        
        ac.reset_actions()  # perform()마다 넣어줘야 한다! 전의 perform들이 사라지는게 아니기 때문. 
        ac.send_keys(Keys.ESCAPE)
        ac.pause(1)
        ac.perform()
        
    time.sleep(5)
    
except Exception as e:
    print(e)
finally:
    d.close()
    d.quit()
# Out:
# [CJ 올리브네트웍스x한국경제신문x퍼브] Remote Internship 4기 참가자 모집
#
# 📢 데이터에 관심있는 2~4학년 경북대생 모두 주목!!
#
# CJ 올리브네트웍스, Firb, 한국경제신문이 함께하는 일·학습 경험 프로그램,
# 리모트인턴십 프로그램에서 데이터 기획/분석 역량을 키우고 현장 실무형 인재로 성장하세요!🙆‍♀️
#
# 🔻간단소개
# - 온라인 가상공간(Metaverse)과 러닝 플랫폼을 활용하여 실제 직장 내 직무 Based 업무를 체험하고 DT역량개발을 지원하는 교육 프로그램
#
# 📅선발일정
# - 신청기간 (*모집인원 충족 시 1차 신청기간 내 조기마감✨)
# 🔥[1차] 2023. 7. 31 ~ 8. 10🔥
# 🔥[2차] 2023. 8. 16 ~ 8. 23 🔥
# - 선발심사: 2023. 8. 28 ~ 9. 1
# - 참가자 확정 및 통보: 2023. 9. 4
#
# 💡교육일정: 2023년 9월 11일(월) ~ 11월 30일(목)
#
# 🔻모집대상
# - 2~4학년
# ※ 졸업예정자 제외, 비전공자·초급자 지원 가능
#
# 📄 교육내용
# - 오리엔테이션 및 팀빌딩
# - 멘토링 (DT분야 실무자와의 비대면 멘토링)
# - 공통역량교육(데이터기획, 통계, 마케팅)
# - 직무별 교육(파이썬, 엑셀, GA, Power BI)
# - 튜터링 및 DS인증
# - 상세안내: https://zrr.kr/EzB6
# - 리모트인턴십 홍보대사 2기 지원 가능 (콘텐츠 제작)
#
# 🎁참가자혜택
# - 전체참가자: 최대 90만원의 참가자 수당 지급, 웰컴키트 지급, DS인증제 통과 시 인증서 제공 등
# - 우수참가자: 취업컨설팅, 심층 인터뷰
# - 최우수참가자: 실제 기업 인턴십, 유관기관 포상(한국지능정보사회진흥원)
#
# 🔻 접수방법
# 👉접수 URL : https://me2.do/5SaZFGIm
# (*포스터QR코드 or 프로필 카카오톡채널 링크도 접속 가능)
#
# 📌 지원서 제출 시 유의사항
# ...

# %%
#
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from openpyxl import Workbook

wb = Workbook()  # workbook의 개념은 파일
ws = wb.active   # worksheet이 여러개 있다. active는 생성했을 때 그 sheet를 선택한 것.

options = webdriver.ChromeOptions()
options.add_argument("--user-data-dir=C:\\Users\\user\\Desktop\\MyChrome")

service = Service()
d = webdriver.Chrome(service=service, options=options)

try:
    d.get("https://www.instagram.com/")    
    time.sleep(5)
    
    buttons = d.find_elements(By.CSS_SELECTOR, ".xvy4d1p")
    search_button = buttons[2]
    
    ac = ActionChains(d)
    ac.move_to_element(search_button)
    ac.click()
    ac.pause(1)
    ac.perform()
    
    elem = d.find_element(By.CSS_SELECTOR, ".x7xwk5j")
    ac = ActionChains(d)
    ac.move_to_element(elem)
    ac.click()
    ac.send_keys("#sql")
    ac.send_keys(Keys.RETURN)
    ac.pause(2)
    ac.move_by_offset(0,100)  # 현재 커서 위치에서 offset 만큼 이동하라
    ac.click()
    ac.perform()
    time.sleep(5)

    posts = d.find_elements(By.CSS_SELECTOR, "._aa8k")
    for post in posts:
        ac = ActionChains(d)
        ac.click(post)
        ac.pause(1)
        ac.perform() 
        
        content = d.find_element(By.CSS_SELECTOR, "._a9zs > ._aade")
        print(content.text)
        ws.append([content.text])
        ac.reset_actions()   # perform()마다 넣어줘야 한다! 전의 perform들이 사라지는게 아니기 때문. 
        ac.send_keys(Keys.ESCAPE) 
        ac.pause(1)
        ac.perform()
        
    time.sleep(5)
    
except Exception as e:
    print(e)
finally:
    d.close()
    d.quit()
    
wb.save("Instagram.xlsx")
# Out:
# 𝗦𝗤𝗟 Interview Questions and Answers 🔥📑📌
#
# Save it ✅
#
# JOIN TELEGRAM FOR MORE CODING RESOURCES AND HANDWRITTEN NOTES
#
# Link 🔗 is in the bio ✅
# https://linktr.ee/manishkumarshah
#
# Follow @codes.manish for more Coding Content.
#
# Credit: @atul.in 💛 follow him for more notes .
#
# #sql #sqldeveloper #datastructure #datastructuresandalgorithms #database #codinggirl #codingbootcamp #programming #codingchallenge #coding #coder #codinglife #code #programmingmemes #programmer #programminglife #programmers #development #developers #developerlife #software #softwaredev #softwareengineer #softwaredeveloper #algorithms #algo #webdesign #webdevelopment #webdeveloper #webdeveloper #interviewquestions
# Do you like histograms?
#
# #pythoncode #datascience #pythonprogrammer #machinelearning #sql #computerscience #dataanalytics #dataanalysis #businessmotivation #businessminded #code #data #sql #dataengineering #datawarehouse #dataanalytics #analytics #programming #webdev #developer
# ...

# %%
# beautifulsoup : 서비스 페이지가 아닌 네이버와 같은 정보 페이지들 위주로 가져올 때 씀 (정적 페이지 : 렌더링 되어 있는 상태)
    # 장점: 매우 빠르게 수집할 수 있다.
    #  
# selenium : 동적 페이지 위주
    # options.add_argument("--headless")  : 브라우저 화면 표시 안되게 하는 것.
    # options.add_argument("--window-size = 1920,1080")  : 화면 크기 조정
