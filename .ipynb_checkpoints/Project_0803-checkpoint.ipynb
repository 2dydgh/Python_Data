# %% [markdown]
# 1) singer 테이블 만들기
# - id (Auto increment 필드)
# - name (가수 이름)
# - follower(팔로우 수)  -> 인증 표시 있을경우만 가져오게 만들기
#
# 2) song 테이블 만들기  -> singer_id를 만들때 FK 누르면 Referenced tabld에서 singer 선택하면 된다.
# - id (Auto increment 필드)
# - singer_id(FK)
# - title(제목)
# - album(앨범)
#
# 3) 멜론 TOP100 을 수집
# - 멜론 TOP100에 존재하는 가수들을 singer 테이블에 저장
#                    -> 이게 어려울것. 중복된 가수가 있을 수 있음. 따라서 기존에 있으면 추가하면 안된다.
# - 각 가수의 곡들은 song 테이블에 저장
# - 단, singer 테이블에서 follower는 0으로 저장
#
# 4) 인스타그램에서 가수명으로 검색한 후 인증마크 달려 있는 계정의 follower 가져와서 데이터베이스의 follower 값 업데이트
#
# 5) Hint!!
#     <가수 저장>
#     1. 멜론 TOP100에서 가수를 읽어옴
#     2. singer 테이블에 가수명 저장 =>insert 구문
#
#     <노래 저장>
#     1. 멜론 TOP100에서 제목, 앨범, 가수명을 읽어옴
#     2. 노래 저장시 필요정보: 제목, 앨범, 가수_id
#     3. DB에서 가수명으로 가수_id를 구함 => Select 구문
#     4. song테이블에 노래 저장 -> insert 구문
#
#     <가수 팔로우 갱신>
#     1. singer 테이블에서 가수 전체를 읽어옴 => cursor.fetchall()
#     2. 가수 전체 정보 : 가수_id, 가수명
#     3. 인스타그램 접속해서 가수명으로 검색
#     4. 인증마크 있는 지 확인, 있으면 클릭
#     5. 인스타그램 계정 페이지에서 팔로워 수 가져옴
#     6. singer 테이블에서 갱신을 하는데 가수_id를 활용해서 follower 업데이트

# %%
# DB 입력 파트

import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import traceback # 에러 발생했을 때 
import pymysql

options = webdriver.ChromeOptions()
options.add_argument("--user-data-dir=C:\\Users\\user\\Desktop\\MyChrome")

db = pymysql.connect(host="localhost", port=3306, user="root", password = "1234", db = "sba")
cursor = db.cursor() 

service = Service()
d = webdriver.Chrome(service=service, options=options)

already = []

try:
    d.get("https://www.melon.com/chart/index.htm?dayTime=2023080314")
    
    area = d.find_element(By.CSS_SELECTOR, ".service_list_song")
    trs = area.find_elements(By.CSS_SELECTOR, "table>tbody>tr")

    for tr in trs:

        singer = tr.find_element(By.CSS_SELECTOR,".ellipsis.rank02 a")
        singer = singer.text.replace("'", "")

        print(singer)
        if singer not in already:
            sql = f""" 
            INSERT INTO singer 
            VALUES
                (NULL, '{singer}',"0");     

            """
            cursor.execute(sql)
            db.commit()
            already.append(singer)

        title = tr.find_element(By.CSS_SELECTOR,".ellipsis.rank01 a")
        album = tr.find_element(By.CSS_SELECTOR,".ellipsis.rank03 a")
        title = title.text.replace("'", "")
        album = album.text.replace("'", "")
        print(title,album)
        
        singer_id= ""
        
        sql = f"""
            SELECT id FROM singer WHERE name='{singer}'
        """
        cursor.execute(sql)
        row = cursor.fetchone()
        singer_id = row[0]
        print(singer_id)
        
        sql = f""" 
        INSERT INTO song 
        VALUES
            (NULL, {singer_id}, '{title}','{album}');

        """
        cursor.execute(sql)
            

    db.commit()
    db.close()
    
except Exception as e:            # except는 필수! 오류났을 경우 error 메시지 출력
    traceback.print_exc()
finally:                          # finally는 선택사항 error가 날지도 모르는 사항
    time.sleep(2)
    d.close()
    d.quit()
# Out:
# NewJeans
# Super Shy NewJeans 2nd EP Get Up
# 101
# 정국
# Seven (feat. Latto) - Clean Ver. Seven (feat. Latto) - Clean Ver.
# 102
# NewJeans
# ETA NewJeans 2nd EP Get Up
# 101
# (여자)아이들
# 퀸카 (Queencard) I feel
# 103
# IVE (아이브)
# I AM Ive IVE
# 104
# 박재정
# 헤어지자 말해요 1집 Alone
# 105
# LE SSERAFIM (르세라핌)
# 이브, 프시케 그리고 푸른 수염의 아내 UNFORGIVEN
# 106
# aespa
# Spicy MY WORLD - The 3rd Mini Album
# 107
# Lauv
# Steal The Show (From “엘리멘탈”) Steal The Show (From “엘리멘탈”)
# 108
# NewJeans
# New Jeans NewJeans 2nd EP Get Up
# 101
# NewJeans
# Hype boy NewJeans 1st EP New Jeans
# 101
# 임영웅
# 사랑은 늘 도망가 신사와 아가씨 OST Part.2
# 109
# IVE (아이브)
# Kitsch Ive IVE
# 104
# LE SSERAFIM (르세라핌)
# UNFORGIVEN (feat. Nile Rodgers) UNFORGIVEN
# 106
# 임영웅
# 모래 알갱이 모래 알갱이
# 109
# 임영웅
# 우리들의 블루스 IM HERO
# 109
# NewJeans
# Ditto NewJeans OMG
# 101
# 임영웅
# 다시 만날 수 있을까 IM HERO
# 109
# 임영웅
# 무지개 IM HERO
# 109
# 임영웅
# 이제 나만 믿어요 내일은 미스터트롯 우승자 특전곡
# 109
# 임영웅
# London Boy Polaroid
# 109
# 임영웅
# Polaroid Polaroid
# 109
# 임영웅
# 아버지 IM HERO
# 109
# 세븐틴 (SEVENTEEN)
# 손오공 SEVENTEEN 10th Mini Album ‘FML
# 111
# NewJeans
# Attention NewJeans 1st EP New Jeans
# 101
# NewJeans
# Cool With You NewJeans 2nd EP Get Up
# 101
# NCT DREAM
# Candy Candy - Winter Special Mini Album
# 110
# NewJeans
# OMG NewJeans OMG
# 101
# 임영웅
# 인생찬가 IM HERO
# 109
# 임영웅
# A bientot IM HERO
# 109
# 지수 (JISOO)
# 꽃 ME
# 112
# 임영웅
# 손이 참 곱던 그대 IM HERO
# 109
# 임영웅
# 사랑해 진짜 IM HERO
# 109
# NCT DREAM
# ISTJ ISTJ - The 3rd Album
# 110
# 방탄소년단
# Dynamite Dynamite (DayTime Version)
# 113
# 임영웅
# 연애편지 IM HERO
# 109
# IVE (아이브)
# After LIKE After LIKE
# 104
# 정국
# Still With You Still With You
# 102
# 윤하 (YOUNHA)
# 사건의 지평선 YOUNHA 6th Album Repackage END THEORY : Final Edition
# 114
# IVE (아이브)
# LOVE DIVE LOVE DIVE
# 104
# Charlie Puth
# I Dont Think That I Like Her CHARLIE
# 115
# 방탄소년단
# Butter Butter
# 113
# 임영웅
# 보금자리 IM HERO
# 109
# NCT DREAM
# Broken Melodies ISTJ - The 3rd Album
# 110
# 부석순 (SEVENTEEN)
# 파이팅 해야지 (Feat. 이영지) 부석순 1st Single Album SECOND WIND
# 116
# Charlie Puth
# Dangerously Nine Track Mind (Deluxe Edition)
# 115
# FIFTY FIFTY
# Cupid The Beginning: Cupid
# 118
# 방탄소년단
# 봄날 YOU NEVER WALK ALONE
# 113
# 방탄소년단
# Take Two Take Two
# 113
# Paul Blanco
# Summer (Feat. BE’O (비오)) Summer
# 121
# 지민
# Like Crazy FACE
# 122
# Agust D
# 사람 Pt.2 (feat. 아이유) D-DAY
# 120
# STAYC(스테이씨)
# Teddy Bear Teddy Bear
# 117
# 방탄소년단
# Permission to Dance Butter / Permission to Dance
# 113
# 정국
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]
# 102
# DK(디셈버)
# 심(心) 심(心)
# 119
# 우디 (Woody)
# 사막에서 꽃을 피우듯 사막에서 꽃을 피우듯
# 127
# NewJeans
# ASAP NewJeans 2nd EP Get Up
# 101
# LE SSERAFIM (르세라핌)
# ANTIFRAGILE ANTIFRAGILE
# 106
# 허각
# 물론 물론
# 125
# 임한별
# 사랑하지 않아서 그랬어 사랑하지 않아서 그랬어
# 124
# H1-KEY (하이키)
# 건물 사이에 피어난 장미 (Rose Blossom) H1-KEY 1st Mini Album [Rose Blossom]
# 123
# 멜로망스
# 사랑인가 봐 사랑인가 봐 (사내맞선 OST 스페셜 트랙)
# 126
# (여자)아이들
# Allergy I feel
# 103
# 성시경
# 너의 모든 순간 별에서 온 그대 OST Part.7
# 128
# ZEROBASEONE (제로베이스원)
# In Bloom YOUTH IN THE SHADE
# 129
# 방탄소년단
# The Planet The Planet
# 113
# 이무진
# 잠깐 시간 될까 잠깐 시간 될까
# 130
# 탑현
# 나에게 그대만이 나에게 그대만이
# 131
# NCT DREAM
# 파랑 (Blue Wave) ISTJ - The 3rd Album
# 110
# The Kid LAROI
# STAY Stay
# 132
# 지아
# 사랑..그게 뭔데 사랑..그게 뭔데
# 133
# j-hope
# on the street (with J. Cole) on the street (with J. Cole)
# 134
# (여자)아이들
# TOMBOY I NEVER DIE
# 103
# 김호중
# 그중에 그대를 만나 삼남매가 용감하게 OST Part.1
# 143
# 임재현
# Heaven(2023) 시작은 첫키스 OST Part.1
# 137
# 김민석 (멜로망스)
# 취중고백 취중고백
# 135
# 경서
# 첫 키스에 내 심장은 120BPM ONGOING
# 136
# NCT DREAM
# Like We Just Met ISTJ - The 3rd Album
# 110
# 오마이걸 (OH MY GIRL)
# 여름이 들려 (Summer Comes) Golden Hourglass
# 145
# Charlie Puth
# Thats Hilarious CHARLIE
# 115
# #안녕
# 해요 (2022) 해요 (2022)
# 139
# 던 (DAWN)
# 빛이 나는 너에게 빛이 나는 너에게
# 140
# imase
# NIGHT DANCER NIGHT DANCER
# 138
# EXO
# Cream Soda EXIST - The 7th Album
# 142
# (여자)아이들
# Nxde I love
# 103
# Charlie Puth
# That’s Not How This Works (feat. Dan + Shay) That’s Not How This Works (feat. Dan + Shay)
# 115
# 케이시 (Kassy)
# 사실말야내가말야그게그러니까말이야 사실말야내가말야그게그러니까말이야
# 141
# NCT DREAM
# Yogurt Shake ISTJ - The 3rd Album
# 110
# 경서예지
# 다정히 내 이름을 부르면 다정히 내 이름을 부르면 (경서예지 x 전건호)
# 144
# NewJeans
# Get Up NewJeans 2nd EP Get Up
# 101
# 테이
# Monologue Monologue
# 146
# NCT DREAM
# Poison (모래성) ISTJ - The 3rd Album
# 110
# NCT DREAM
# Skateboard ISTJ - The 3rd Album
# 110
# 제이세라
# 사랑의 바보 사랑의 바보
# 148
# NCT DREAM
# SOS ISTJ - The 3rd Album
# 110
# 이채연
# KNOCK Over The Moon
# 147
# NCT DREAM
# Pretzel (♡) ISTJ - The 3rd Album
# 110
# NCT DREAM
# 제자리 걸음 (Starry Night) ISTJ - The 3rd Album
# 110
# 로이킴
# 잘 지내자, 우리 (여름날 우리 X 로이킴) 잘 지내자, 우리 (여름날 우리 X 로이킴)
# 990

# %%
# instagram 파트

import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import traceback # 에러 발생했을 때 
import pymysql

options = webdriver.ChromeOptions()
options.add_argument("--user-data-dir=C:\\Users\\user\\Desktop\\MyChrome")

db = pymysql.connect(host="localhost", port=3306, user="root", password = "1234", db = "sba")
cursor = db.cursor() 

service = Service()
d = webdriver.Chrome(service=service, options=options)

sql = "SELECT * FROM singer"
cursor.execute(sql)
rows = cursor.fetchall()
try:   
    for row in rows:
       
        # Instagram 검색 시작
        d.get("https://www.instagram.com/")    
        time.sleep(5)

        buttons = d.find_elements(By.CSS_SELECTOR, ".xvy4d1p")
        search_button = buttons[2]

        ac = ActionChains(d)
        ac.move_to_element(search_button)
        ac.click()
        ac.pause(1)
        ac.perform()

        elem = d.find_element(By.CSS_SELECTOR, ".x7xwk5j")
        ac = ActionChains(d)
        ac.move_to_element(elem)
        ac.click()

        ac.send_keys(f'{row[1]}')
        ac.send_keys(Keys.RETURN)
        ac.pause(2)
        ac.perform()
                
        tmp = "x9f619 xjbqb8w x1rg5ohu x168nmei x13lgxp2 x5pf9jr xo71vjh xsgj6o6 x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1"
        tmp = tmp.split(" ")
        tmp = "." + ".".join(tmp)

        marks = d.find_elements(By.CSS_SELECTOR, tmp)
        if marks:
            ac.click(marks[0])
            ac.pause(2)
            ac.perform()
        
            follow = d.find_element(By.CSS_SELECTOR, "._a6hd > ._ac2a").text.replace("'", "")
# 다른 방법 :
#             elem = d.find_elements(By.CSS_SELECTOR,".ac2a")
#             follower_str = elem[1].text.strip()
#             follower_count = 1
#             if follower_str[-1] == "만":
#                 follower_count = 10000
                
#             follower_str = follower_str.replace("만", "")
#             follower_count *= float(folower_str)
#             print(follower_count)
            
            
            print(f"Instagram 팔로우 수: {follow}")
            time.sleep(5)
        
            
    
        
except Exception as e:            # except는 필수! 오류났을 경우 error 메시지 출력
    traceback.print_exc()
finally:                          # finally는 선택사항 error가 날지도 모르는 사항
    time.sleep(2)
    d.close()
    d.quit()

# %%
# 인증 hint

tmp = "x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1gslohp x1i64zmx x1n2onr6 x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1"
tmp = tmp.split(" ")
tmp = "." + ".".join(tmp)

marks = d.find_elements(By.CSS_SELECTOR, tmp)
if marks:
    ac.click(marks[0])

# %%
# ~만 숫자로 바꾸기

follower_str = "878.5만"

follower_count = 1
if follower_count
